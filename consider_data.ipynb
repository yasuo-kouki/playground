# %%
import numpy as np
import pandas as pd

train = pd.read_csv('data/train.csv')
predict = pd.read_csv('data/test.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           750000 non-null  int64
#  1   Podcast_Name                 750000 non-null  object
#  2   Episode_Title                750000 non-null  object
#  3   Episode_Length_minutes       662907 non-null  float64
#  4   Genre                        750000 non-null  object
#  5   Host_Popularity_percentage   750000 non-null  float64
#  6   Publication_Day              750000 non-null  object
#  7   Publication_Time             750000 non-null  object
#  8   Guest_Popularity_percentage  603970 non-null  float64
#  9   Number_of_Ads                749999 non-null  float64
#  10  Episode_Sentiment            750000 non-null  object
#  11  Listening_Time_minutes       750000 non-null  float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 68.7+ MB

# %%
predict.describe().T
# Out:
#                                 count           mean            std  \
# id                           250000.0  874999.500000   72168.927986
# Episode_Length_minutes       221264.0     419.298741  166854.502468
# Host_Popularity_percentage   250000.0      59.716491      22.880028
# Guest_Popularity_percentage  201168.0      52.192796      28.445034
# Number_of_Ads                250000.0       1.355852       4.274399
#
#                                    min        25%        50%        75%  \
# id                           750000.00  812499.75  874999.50  937499.25
# Episode_Length_minutes            2.47      35.78      63.97      94.15
# Host_Popularity_percentage        2.49      39.25      59.90      79.39
# Guest_Popularity_percentage       0.00      28.32      53.36      76.56
# Number_of_Ads                     0.00       0.00       1.00       2.00
#
#                                      max
# id                             999999.00
# Episode_Length_minutes       78486264.00
# Host_Popularity_percentage        117.76
# Guest_Popularity_percentage       116.82
# Number_of_Ads                    2063.00

# %%
train.describe().T
# Out:
#                                 count           mean            std  min  \
# id                           750000.0  374999.500000  216506.495284  0.0
# Episode_Length_minutes       662907.0      64.504738      32.969603  0.0
# Host_Popularity_percentage   750000.0      59.859901      22.873098  1.3
# Guest_Popularity_percentage  603970.0      52.236449      28.451241  0.0
# Number_of_Ads                749999.0       1.348855       1.151130  0.0
# Listening_Time_minutes       750000.0      45.437406      27.138306  0.0
#
#                                       25%           50%           75%  \
# id                           187499.75000  374999.50000  562499.25000
# Episode_Length_minutes           35.73000      63.84000      94.07000
# Host_Popularity_percentage       39.41000      60.05000      79.53000
# Guest_Popularity_percentage      28.38000      53.58000      76.60000
# Number_of_Ads                     0.00000       1.00000       2.00000
# Listening_Time_minutes           23.17835      43.37946      64.81158
#
#                                    max
# id                           749999.00
# Episode_Length_minutes          325.24
# Host_Popularity_percentage      119.46
# Guest_Popularity_percentage     119.91
# Number_of_Ads                   103.91
# Listening_Time_minutes          119.97

# %%
predict.nunique()
# Out:
# id                             250000
# Podcast_Name                       48
# Episode_Title                     100
# Episode_Length_minutes          11631
# Genre                              10
# Host_Popularity_percentage       8010
# Publication_Day                     7
# Publication_Time                    4
# Guest_Popularity_percentage      9961
# Number_of_Ads                       6
# Episode_Sentiment                   3
# dtype: int64

# %%
train.nunique()
# Out:
# id                             750000
# Podcast_Name                       48
# Episode_Title                     100
# Episode_Length_minutes          12268
# Genre                              10
# Host_Popularity_percentage       8038
# Publication_Day                     7
# Publication_Time                    4
# Guest_Popularity_percentage     10019
# Number_of_Ads                      12
# Episode_Sentiment                   3
# Listening_Time_minutes          42807
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# サブプロットの準備（横に2つ）
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# train データのヒストグラム + KDE
sns.histplot(train['Listening_Time_minutes'].dropna(), kde=True, bins=50, ax=axs[0])
axs[0].set_title('Train: Episode_Length_minutes')
#axs[0].set_xlabel('Episode_Length_minutes')

# predict データのヒストグラム + KDE
sns.histplot(predict['Episode_Sentiment'].dropna(), kde=True, bins=50, ax=axs[1])
axs[1].set_title('Predict: Episode_Length_minutes')
#axs[1].set_xlabel('Episode_Length_minutes')

# レイアウト調整して表示
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# サブプロットの準備（横に2つ）
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# train データのヒストグラム + KDE
sns.histplot(train['Episode_Sentiment'].dropna(), kde=True, bins=50, ax=axs[0])
axs[0].set_title('Train: Episode_Length_minutes')
#axs[0].set_xlabel('Episode_Length_minutes')

# predict データのヒストグラム + KDE
sns.histplot(predict['Episode_Sentiment'].dropna(), kde=True, bins=50, ax=axs[1])
axs[1].set_title('Predict: Episode_Length_minutes')
#axs[1].set_xlabel('Episode_Length_minutes')

# レイアウト調整して表示
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# サブプロットの準備（横に2つ）
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# train データのヒストグラム + KDE
sns.histplot(train['Number_of_Ads'].dropna(), kde=True, bins=50, ax=axs[0])
axs[0].set_title('Train: Episode_Length_minutes')
#axs[0].set_xlabel('Episode_Length_minutes')

# predict データのヒストグラム + KDE
sns.histplot(predict['Number_of_Ads'].dropna(), kde=True, bins=50, ax=axs[1])
axs[1].set_title('Predict: Episode_Length_minutes')
#axs[1].set_xlabel('Episode_Length_minutes')

# レイアウト調整して表示
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# サブプロットの準備（横に2つ）
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# train データのヒストグラム + KDE
sns.histplot(train['Guest_Popularity_percentage'].dropna(), kde=True, bins=50, ax=axs[0])
axs[0].set_title('Train: Episode_Length_minutes')
#axs[0].set_xlabel('Episode_Length_minutes')

# predict データのヒストグラム + KDE
sns.histplot(predict['Guest_Popularity_percentage'].dropna(), kde=True, bins=50, ax=axs[1])
axs[1].set_title('Predict: Episode_Length_minutes')
#axs[1].set_xlabel('Episode_Length_minutes')

# レイアウト調整して表示
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# サブプロットの準備（横に2つ）
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# train データのヒストグラム + KDE
sns.histplot(train['Publication_Time'].dropna(), kde=True, bins=50, ax=axs[0])
axs[0].set_title('Train: Episode_Length_minutes')
#axs[0].set_xlabel('Episode_Length_minutes')

# predict データのヒストグラム + KDE
sns.histplot(predict['Publication_Time'].dropna(), kde=True, bins=50, ax=axs[1])
axs[1].set_title('Predict: Episode_Length_minutes')
#axs[1].set_xlabel('Episode_Length_minutes')

# レイアウト調整して表示
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# サブプロットの準備（横に2つ）
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# train データのヒストグラム + KDE
sns.histplot(train['Publication_Day'].dropna(), kde=True, bins=50, ax=axs[0])
axs[0].set_title('Train: Episode_Length_minutes')
#axs[0].set_xlabel('Episode_Length_minutes')

# predict データのヒストグラム + KDE
sns.histplot(predict['Publication_Day'].dropna(), kde=True, bins=50, ax=axs[1])
axs[1].set_title('Predict: Episode_Length_minutes')
#axs[1].set_xlabel('Episode_Length_minutes')

# レイアウト調整して表示
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# サブプロットの準備（横に2つ）
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# train データのヒストグラム + KDE
sns.histplot(train['Genre'].dropna(), kde=True, bins=50, ax=axs[0])
axs[0].set_title('Train: Episode_Length_minutes')
#axs[0].set_xlabel('Episode_Length_minutes')

# predict データのヒストグラム + KDE
sns.histplot(predict['Genre'].dropna(), kde=True, bins=50, ax=axs[1])
axs[1].set_title('Predict: Episode_Length_minutes')
#axs[1].set_xlabel('Episode_Length_minutes')

# レイアウト調整して表示
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# サブプロットの準備（横に2つ）
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# train データのヒストグラム + KDE
sns.histplot(train['Episode_Length_minutes'].dropna(), kde=True, bins=50, ax=axs[0])
axs[0].set_title('Train: Episode_Length_minutes')
#axs[0].set_xlabel('Episode_Length_minutes')

# predict データのヒストグラム + KDE
sns.histplot(predict['Episode_Length_minutes'].dropna(), kde=True, bins=50, ax=axs[1])
axs[1].set_title('Predict: Episode_Length_minutes')
#axs[1].set_xlabel('Episode_Length_minutes')

# レイアウト調整して表示
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# サブプロットを作成
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# trianデータのヒストグラム
axs[0].hist(train['Episode_Length_minutes'].dropna(), bins=20)
axs[0].set_xlabel('Host_Popularity_percentage')
axs[0].set_ylabel('Frequency')
axs[0].set_title('Distribution of Host_Popularity_percentage (trian)')

# predictデータのヒストグラム
axs[1].hist(predict['Episode_Length_minutes'].dropna(), bins=20)
axs[1].set_xlabel('Host_Popularity_percentage')
axs[1].set_ylabel('Frequency')
axs[1].set_title('Distribution of Host_Popularity_percentage (predict)')

# 表示
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# サブプロットを作成
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# trianデータのヒストグラム
axs[0].hist(train['Host_Popularity_percentage'].dropna(), bins=100)
axs[0].set_xlabel('Host_Popularity_percentage')
axs[0].set_ylabel('Frequency')
axs[0].set_title('Distribution of Host_Popularity_percentage (trian)')

# predictデータのヒストグラム
axs[1].hist(predict['Host_Popularity_percentage'].dropna(), bins=100)
axs[1].set_xlabel('Host_Popularity_percentage')
axs[1].set_ylabel('Frequency')
axs[1].set_title('Distribution of Host_Popularity_percentage (predict)')

# 表示
plt.tight_layout()
plt.show()
