# %% [markdown]
# # 1st delete NaN

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('data/train.csv')
predict = pd.read_csv('data/test.csv')

# %%
passenger_id = predict[['id']].copy()

# %%
train.head()
# Out:
#    id     Podcast_Name Episode_Title  Episode_Length_minutes       Genre  \
# 0   0  Mystery Matters    Episode 98                     NaN  True Crime
# 1   1    Joke Junction    Episode 26                  119.80      Comedy
# 2   2   Study Sessions    Episode 16                   73.90   Education
# 3   3   Digital Digest    Episode 45                   67.17  Technology
# 4   4      Mind & Body    Episode 86                  110.51      Health
#
#    Host_Popularity_percentage Publication_Day Publication_Time  \
# 0                       74.81        Thursday            Night
# 1                       66.95        Saturday        Afternoon
# 2                       69.97         Tuesday          Evening
# 3                       57.22          Monday          Morning
# 4                       80.07          Monday        Afternoon
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                          NaN            0.0          Positive
# 1                        75.95            2.0          Negative
# 2                         8.97            0.0          Negative
# 3                        78.70            2.0          Positive
# 4                        58.68            3.0           Neutral
#
#    Listening_Time_minutes
# 0                31.41998
# 1                88.01241
# 2                44.92531
# 3                46.27824
# 4                75.61031

# %%
train.describe().T
# Out:
#                                 count           mean            std  min  \
# id                           750000.0  374999.500000  216506.495284  0.0
# Episode_Length_minutes       662907.0      64.504738      32.969603  0.0
# Host_Popularity_percentage   750000.0      59.859901      22.873098  1.3
# Guest_Popularity_percentage  603970.0      52.236449      28.451241  0.0
# Number_of_Ads                749999.0       1.348855       1.151130  0.0
# Listening_Time_minutes       750000.0      45.437406      27.138306  0.0
#
#                                       25%           50%           75%  \
# id                           187499.75000  374999.50000  562499.25000
# Episode_Length_minutes           35.73000      63.84000      94.07000
# Host_Popularity_percentage       39.41000      60.05000      79.53000
# Guest_Popularity_percentage      28.38000      53.58000      76.60000
# Number_of_Ads                     0.00000       1.00000       2.00000
# Listening_Time_minutes           23.17835      43.37946      64.81158
#
#                                    max
# id                           749999.00
# Episode_Length_minutes          325.24
# Host_Popularity_percentage      119.46
# Guest_Popularity_percentage     119.91
# Number_of_Ads                   103.91
# Listening_Time_minutes          119.97

# %%
predict.isnull().sum()
# Out:
# id                                 0
# Podcast_Name                       0
# Episode_Title                      0
# Episode_Length_minutes         28736
# Genre                              0
# Host_Popularity_percentage         0
# Publication_Day                    0
# Publication_Time                   0
# Guest_Popularity_percentage    48832
# Number_of_Ads                      0
# Episode_Sentiment                  0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# id                                  0
# Podcast_Name                        0
# Episode_Title                       0
# Episode_Length_minutes          87093
# Genre                               0
# Host_Popularity_percentage          0
# Publication_Day                     0
# Publication_Time                    0
# Guest_Popularity_percentage    146030
# Number_of_Ads                       1
# Episode_Sentiment                   0
# Listening_Time_minutes              0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           750000 non-null  int64
#  1   Podcast_Name                 750000 non-null  object
#  2   Episode_Title                750000 non-null  object
#  3   Episode_Length_minutes       662907 non-null  float64
#  4   Genre                        750000 non-null  object
#  5   Host_Popularity_percentage   750000 non-null  float64
#  6   Publication_Day              750000 non-null  object
#  7   Publication_Time             750000 non-null  object
#  8   Guest_Popularity_percentage  603970 non-null  float64
#  9   Number_of_Ads                749999 non-null  float64
#  10  Episode_Sentiment            750000 non-null  object
#  11  Listening_Time_minutes       750000 non-null  float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 68.7+ MB

# %%
train.nunique()
# Out:
# id                             750000
# Podcast_Name                       48
# Episode_Title                     100
# Episode_Length_minutes          12268
# Genre                              10
# Host_Popularity_percentage       8038
# Publication_Day                     7
# Publication_Time                    4
# Guest_Popularity_percentage     10019
# Number_of_Ads                      12
# Episode_Sentiment                   3
# Listening_Time_minutes          42807
# dtype: int64

# %%
train.head()
# Out:
#    id     Podcast_Name Episode_Title  Episode_Length_minutes       Genre  \
# 0   0  Mystery Matters    Episode 98                     NaN  True Crime
# 1   1    Joke Junction    Episode 26                  119.80      Comedy
# 2   2   Study Sessions    Episode 16                   73.90   Education
# 3   3   Digital Digest    Episode 45                   67.17  Technology
# 4   4      Mind & Body    Episode 86                  110.51      Health
#
#    Host_Popularity_percentage Publication_Day Publication_Time  \
# 0                       74.81        Thursday            Night
# 1                       66.95        Saturday        Afternoon
# 2                       69.97         Tuesday          Evening
# 3                       57.22          Monday          Morning
# 4                       80.07          Monday        Afternoon
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                          NaN            0.0          Positive
# 1                        75.95            2.0          Negative
# 2                         8.97            0.0          Negative
# 3                        78.70            2.0          Positive
# 4                        58.68            3.0           Neutral
#
#    Listening_Time_minutes
# 0                31.41998
# 1                88.01241
# 2                44.92531
# 3                46.27824
# 4                75.61031

# %% [markdown]
# # Preprocessing of data

# %%
def create_features(df):
    df[['Episode_Name','Episode_Num']] = df['Episode_Title'].str.split(' ', expand=True)
    df['Episode_Num'] = df['Episode_Num'].astype(int)
    return df

train = create_features(train)
predict = create_features(predict)

# %%
# columns to drop 
def delete_columns(df):
    #df.drop(columns=['id','Episode_Title','Episode_Length_minutes','Guest_Popularity_percentage'], inplace=True)
    df.drop(columns=['id','Episode_Title'], inplace=True)
    return df

train = delete_columns(train)
predict = delete_columns(predict)

# %%
train.head()
# Out:
#       Podcast_Name  Episode_Length_minutes       Genre  \
# 0  Mystery Matters                     NaN  True Crime
# 1    Joke Junction                  119.80      Comedy
# 2   Study Sessions                   73.90   Education
# 3   Digital Digest                   67.17  Technology
# 4      Mind & Body                  110.51      Health
#
#    Host_Popularity_percentage Publication_Day Publication_Time  \
# 0                       74.81        Thursday            Night
# 1                       66.95        Saturday        Afternoon
# 2                       69.97         Tuesday          Evening
# 3                       57.22          Monday          Morning
# 4                       80.07          Monday        Afternoon
#
#    Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 0                          NaN            0.0          Positive
# 1                        75.95            2.0          Negative
# 2                         8.97            0.0          Negative
# 3                        78.70            2.0          Positive
# 4                        58.68            3.0           Neutral
#
#    Listening_Time_minutes Episode_Name  Episode_Num
# 0                31.41998      Episode           98
# 1                88.01241      Episode           26
# 2                44.92531      Episode           16
# 3                46.27824      Episode           45
# 4                75.61031      Episode           86

# %% [markdown]
# # Data preparation before modeling

# %% [markdown]
# ### Since there are few tpyes of object data,label encoding will be applied

# %%
# Label Encoding
from sklearn.preprocessing import LabelEncoder

def label_enocding(df,columns):
    le = LabelEncoder()

    for col in columns:
        df[col] = le.fit_transform(df[col])
    return df

encoding_cols = ['Podcast_Name','Genre','Publication_Day',
                 'Publication_Time','Episode_Sentiment','Episode_Name']

train = label_enocding(train, encoding_cols)
predict = label_enocding(predict, encoding_cols)

# %%
train.head()
# Out:
#    Podcast_Name  Episode_Length_minutes  Genre  Host_Popularity_percentage  \
# 0            34                     NaN      9                       74.81
# 1            24                  119.80      1                       66.95
# 2            40                   73.90      2                       69.97
# 3            10                   67.17      8                       57.22
# 4            31                  110.51      3                       80.07
#
#    Publication_Day  Publication_Time  Guest_Popularity_percentage  \
# 0                4                 3                          NaN
# 1                2                 0                        75.95
# 2                5                 1                         8.97
# 3                1                 2                        78.70
# 4                1                 0                        58.68
#
#    Number_of_Ads  Episode_Sentiment  Listening_Time_minutes  Episode_Name  \
# 0            0.0                  2                31.41998             0
# 1            2.0                  0                88.01241             0
# 2            0.0                  0                44.92531             0
# 3            2.0                  2                46.27824             0
# 4            3.0                  1                75.61031             0
#
#    Episode_Num
# 0           98
# 1           26
# 2           16
# 3           45
# 4           86

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Podcast_Name                 750000 non-null  int64
#  1   Episode_Length_minutes       662907 non-null  float64
#  2   Genre                        750000 non-null  int64
#  3   Host_Popularity_percentage   750000 non-null  float64
#  4   Publication_Day              750000 non-null  int64
#  5   Publication_Time             750000 non-null  int64
#  6   Guest_Popularity_percentage  603970 non-null  float64
#  7   Number_of_Ads                749999 non-null  float64
#  8   Episode_Sentiment            750000 non-null  int64
#  9   Listening_Time_minutes       750000 non-null  float64
#  10  Episode_Name                 750000 non-null  int64
#  11  Episode_Num                  750000 non-null  int64
# dtypes: float64(5), int64(7)
# memory usage: 68.7 MB

# %%
from sklearn.model_selection import train_test_split

def split_data(df, test_size=0.2, random_state=42):
    X = df.drop(columns=['Listening_Time_minutes'])
    y = df['Listening_Time_minutes']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = split_data(train)
predict_X = predict.copy()

# %% [markdown]
# # Model Construction

# %%
import xgboost as xgb

# XGBoostモデルの構築
def build_xgboost_model(n_estimators=100,max_depth=5,learning_rate=0.1):
    """XGBoostモデルを構築する関数"""
    model = xgb.XGBRegressor(
        # 回帰タスクに適した損失関数（MSE）
        objextive='reg:squarederror',
        # 決定木の数
        n_estimators=n_estimators,
        # 決定機の深さ
        max_depth=max_depth,
        # 学習率(小さいほど安定，収束が遅くなる)
        learning_rate=learning_rate,
        # 乱数シード
        random_state=42
    )
    return model

# XGBoostモデルの構築
xgb_X_train = X_train
xgb_X_test = X_test

# モデルの構築
xgb_model = build_xgboost_model()

# %%
import matplotlib.pyplot as plt

# Train XGBoost model
xgb_model.fit(X_train, y_train) # XGBoostモデルの学習

# Feature importance
xgb.plot_importance(xgb_model) # 特徴量の重要度をプロット
plt.title('XGBoost Feature Importance') # タイトル
plt.show() # グラフの表示
# Out:
# /Users/yasuo/myenv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [12:11:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "objextive" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %% [markdown]
# # Model evalution

# %%
xgb_pred = xgb_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
def evaluate_metrics(y_true,y_pred):
    
    results = []

    def calulate_metrics(y_true, y_pred):
        mse = mean_squared_error(y_true, y_pred)
        mae = mean_absolute_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)

        return {
            'MSE': mse,
            'RMSE': mae,
            'R2': r2
        }
    results.append(calulate_metrics(y_true, y_pred))

    return pd.DataFrame(results)

results = evaluate_metrics(y_test, xgb_pred)
display(results)
# Out:
#           MSE      RMSE        R2
# 0  170.740295  9.512983  0.767961

# %%
import shap

def explain_model(model):
    # SHAP explainerを作成（TreeExplainerはXGBoostなどに最適）
    explainer = shap.Explainer(model)

    # SHAP値を計算（X_testに対して）
    shap_values = explainer(X_test)

    # 可視化（例：1件目の予測理由）
    shap.plots.waterfall(shap_values[0])

    # 全体の特徴量の影響（要約プロット）
    shap.plots.beeswarm(shap_values)

explain_model(xgb_model)

# %% [markdown]
# # Optuna

# %%
import optuna
def optimize_xgboost(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 500), # 決定木の数
        'max_depth': trial.suggest_int('max_depth', 3, 10), # 決定木の深さ
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3), # 学習率
        'subsample': trial.suggest_float('subsample', 0.6, 1.0), # サブサンプル
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0), # 列のサブサンプル
        'gamma': trial.suggest_float('gamma', 0, 1), # 葉ノードを分割するために必要な最小損失削減
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # 葉ノードの重みの最小合計
        'objective': 'reg:squarederror', # 回帰タスクに適した損失関数
        'random_state': 42                
    }

    model = xgb.XGBRegressor(**params)
    model = model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)

    return mse

study = optuna.create_study(direction='minimize')
study.optimize(optimize_xgboost, n_trials=50)

# dislay best results
print('Best trial:')
trial = study.best_trial # 最良のトライアル
print(f"  MSE: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# Predict
optimized_xgb = xgb.XGBRegressor(**trial.params, random_state=42)
optimized_xgb.fit(X_train, y_train)
# Out:
# [I 2025-04-14 12:11:59,664] A new study created in memory with name: no-name-5586ae0c-2723-4eed-9969-923d5b6d6b87
# [I 2025-04-14 12:12:01,760] Trial 0 finished with value: 169.29983856788843 and parameters: {'n_estimators': 279, 'max_depth': 5, 'learning_rate': 0.09051593011874057, 'subsample': 0.8057689176752242, 'colsample_bytree': 0.9745198448750378, 'gamma': 0.764335110279646, 'min_child_weight': 1}. Best is trial 0 with value: 169.29983856788843.
# [I 2025-04-14 12:12:06,314] Trial 1 finished with value: 165.95582880355641 and parameters: {'n_estimators': 410, 'max_depth': 8, 'learning_rate': 0.09772148238288647, 'subsample': 0.6776520396181794, 'colsample_bytree': 0.9103328046901058, 'gamma': 0.7650475630872478, 'min_child_weight': 2}. Best is trial 1 with value: 165.95582880355641.
# [I 2025-04-14 12:12:07,313] Trial 2 finished with value: 172.0673956409885 and parameters: {'n_estimators': 191, 'max_depth': 3, 'learning_rate': 0.07733125374625939, 'subsample': 0.696454459686165, 'colsample_bytree': 0.8889410699886592, 'gamma': 0.07436555191054894, 'min_child_weight': 1}. Best is trial 1 with value: 165.95582880355641.
# [I 2025-04-14 12:12:08,470] Trial 3 finished with value: 168.86813819047848 and parameters: {'n_estimators': 107, 'max_depth': 7, 'learning_rate': 0.14066877156018023, 'subsample': 0.666513766960987, 'colsample_bytree': 0.9016701140064957, 'gamma': 0.011365728570088995, 'min_child_weight': 1}. Best is trial 1 with value: 165.95582880355641.
# [I 2025-04-14 12:12:12,820] Trial 4 finished with value: 166.88686956914347 and parameters: {'n_estimators': 463, 'max_depth': 7, 'learning_rate': 0.10959039672945754, 'subsample': 0.6221456721510085, 'colsample_bytree': 0.707184492379998, 'gamma': 0.9152903938429928, 'min_child_weight': 5}. Best is trial 1 with value: 165.95582880355641.
# [I 2025-04-14 12:12:17,756] Trial 5 finished with value: 164.81076237268059 and parameters: {'n_estimators': 328, 'max_depth': 10, 'learning_rate': 0.11116473065069664, 'subsample': 0.7747560020066265, 'colsample_bytree': 0.984507091396946, 'gamma': 0.9086645473688747, 'min_child_weight': 1}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:19,778] Trial 6 finished with value: 165.99630394524257 and parameters: {'n_estimators': 161, 'max_depth': 9, 'learning_rate': 0.13164359463176412, 'subsample': 0.9906510956342386, 'colsample_bytree': 0.9981286863850685, 'gamma': 0.12472449112676198, 'min_child_weight': 3}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:24,940] Trial 7 finished with value: 168.64397850125482 and parameters: {'n_estimators': 285, 'max_depth': 10, 'learning_rate': 0.01727322928914551, 'subsample': 0.9507616087663072, 'colsample_bytree': 0.7390737981612258, 'gamma': 0.07534020903027439, 'min_child_weight': 9}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:28,333] Trial 8 finished with value: 167.26545138750916 and parameters: {'n_estimators': 368, 'max_depth': 7, 'learning_rate': 0.07677969404642696, 'subsample': 0.8989092173213222, 'colsample_bytree': 0.7703733406125832, 'gamma': 0.20194109142363603, 'min_child_weight': 10}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:30,327] Trial 9 finished with value: 168.67332615851936 and parameters: {'n_estimators': 137, 'max_depth': 10, 'learning_rate': 0.25715369662168314, 'subsample': 0.9325162830958099, 'colsample_bytree': 0.6284232049081807, 'gamma': 0.11410438106724885, 'min_child_weight': 8}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:32,606] Trial 10 finished with value: 168.5022450112462 and parameters: {'n_estimators': 344, 'max_depth': 5, 'learning_rate': 0.21402428074895177, 'subsample': 0.7951124462652929, 'colsample_bytree': 0.8447168452799155, 'gamma': 0.4447353214929004, 'min_child_weight': 5}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:39,238] Trial 11 finished with value: 166.3934180922245 and parameters: {'n_estimators': 483, 'max_depth': 9, 'learning_rate': 0.02330230922380362, 'subsample': 0.759292055695687, 'colsample_bytree': 0.9267819009178039, 'gamma': 0.7134445220291539, 'min_child_weight': 3}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:44,334] Trial 12 finished with value: 170.14884992068332 and parameters: {'n_estimators': 401, 'max_depth': 9, 'learning_rate': 0.18844111659419627, 'subsample': 0.735249063230398, 'colsample_bytree': 0.8335860761678222, 'gamma': 0.9944457137781256, 'min_child_weight': 3}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:48,569] Trial 13 finished with value: 167.0150492953215 and parameters: {'n_estimators': 404, 'max_depth': 8, 'learning_rate': 0.17501974030685452, 'subsample': 0.8415732585515294, 'colsample_bytree': 0.9377271184588746, 'gamma': 0.6555882435127874, 'min_child_weight': 7}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:51,219] Trial 14 finished with value: 167.8472994260972 and parameters: {'n_estimators': 217, 'max_depth': 8, 'learning_rate': 0.05609246299957585, 'subsample': 0.6233596430998776, 'colsample_bytree': 0.9980656690633749, 'gamma': 0.5021892278817912, 'min_child_weight': 3}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:56,231] Trial 15 finished with value: 181.56003012839506 and parameters: {'n_estimators': 325, 'max_depth': 10, 'learning_rate': 0.29036952725242315, 'subsample': 0.7014547322388713, 'colsample_bytree': 0.8572242462653095, 'gamma': 0.813160174438714, 'min_child_weight': 2}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:12:59,172] Trial 16 finished with value: 168.222393201334 and parameters: {'n_estimators': 455, 'max_depth': 5, 'learning_rate': 0.12258990878595724, 'subsample': 0.8635768368504553, 'colsample_bytree': 0.9430612588184443, 'gamma': 0.576776392575957, 'min_child_weight': 6}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:02,249] Trial 17 finished with value: 168.006604616171 and parameters: {'n_estimators': 246, 'max_depth': 8, 'learning_rate': 0.04788105408709413, 'subsample': 0.7513468568995509, 'colsample_bytree': 0.8038268248870796, 'gamma': 0.8714576795668911, 'min_child_weight': 4}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:05,775] Trial 18 finished with value: 167.78051094947313 and parameters: {'n_estimators': 413, 'max_depth': 6, 'learning_rate': 0.16625914729737265, 'subsample': 0.6679833929939379, 'colsample_bytree': 0.8823260442843968, 'gamma': 0.3953017564875214, 'min_child_weight': 2}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:06,584] Trial 19 finished with value: 168.16640472107593 and parameters: {'n_estimators': 51, 'max_depth': 9, 'learning_rate': 0.22784640836362757, 'subsample': 0.7886455276698181, 'colsample_bytree': 0.9519978066214312, 'gamma': 0.9941116912916232, 'min_child_weight': 2}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:11,530] Trial 20 finished with value: 165.61507499120523 and parameters: {'n_estimators': 314, 'max_depth': 10, 'learning_rate': 0.1011966876618432, 'subsample': 0.7098456268313603, 'colsample_bytree': 0.6009935783969724, 'gamma': 0.32395720819090407, 'min_child_weight': 4}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:16,238] Trial 21 finished with value: 165.70449459935344 and parameters: {'n_estimators': 311, 'max_depth': 10, 'learning_rate': 0.10816597841972055, 'subsample': 0.7193917111774712, 'colsample_bytree': 0.6046005416864185, 'gamma': 0.2831047949245315, 'min_child_weight': 4}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:20,858] Trial 22 finished with value: 166.12624520551952 and parameters: {'n_estimators': 310, 'max_depth': 10, 'learning_rate': 0.1323929130751735, 'subsample': 0.7272925961964122, 'colsample_bytree': 0.6052506658559476, 'gamma': 0.3068995009375447, 'min_child_weight': 6}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:24,450] Trial 23 finished with value: 166.51779572666504 and parameters: {'n_estimators': 244, 'max_depth': 10, 'learning_rate': 0.1554532219648985, 'subsample': 0.832106706616213, 'colsample_bytree': 0.668943298491247, 'gamma': 0.2759456638481306, 'min_child_weight': 4}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:29,023] Trial 24 finished with value: 165.5959232803258 and parameters: {'n_estimators': 356, 'max_depth': 9, 'learning_rate': 0.06695662271322048, 'subsample': 0.769757238848572, 'colsample_bytree': 0.66681721160173, 'gamma': 0.37078929447541253, 'min_child_weight': 4}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:33,774] Trial 25 finished with value: 166.13741890979983 and parameters: {'n_estimators': 359, 'max_depth': 9, 'learning_rate': 0.04840955392418021, 'subsample': 0.7757532064991277, 'colsample_bytree': 0.6546071894760417, 'gamma': 0.38137507000748433, 'min_child_weight': 7}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:35,516] Trial 26 finished with value: 171.55060603201707 and parameters: {'n_estimators': 373, 'max_depth': 3, 'learning_rate': 0.07290175624906672, 'subsample': 0.8222587859839442, 'colsample_bytree': 0.7062770125428011, 'gamma': 0.5536515189720916, 'min_child_weight': 5}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:39,312] Trial 27 finished with value: 167.17588963638786 and parameters: {'n_estimators': 268, 'max_depth': 9, 'learning_rate': 0.04093652265644828, 'subsample': 0.8743770895473364, 'colsample_bytree': 0.7025773641736048, 'gamma': 0.3565550981976942, 'min_child_weight': 4}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:44,281] Trial 28 finished with value: 165.0750782029227 and parameters: {'n_estimators': 331, 'max_depth': 10, 'learning_rate': 0.06949936578093857, 'subsample': 0.6417646533596341, 'colsample_bytree': 0.6609405325994978, 'gamma': 0.6407552117737995, 'min_child_weight': 7}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:46,017] Trial 29 finished with value: 170.8850277766865 and parameters: {'n_estimators': 281, 'max_depth': 4, 'learning_rate': 0.0677593321414017, 'subsample': 0.6380351493180861, 'colsample_bytree': 0.7454094152725577, 'gamma': 0.6648303212692277, 'min_child_weight': 7}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:49,480] Trial 30 finished with value: 181.16593255249714 and parameters: {'n_estimators': 337, 'max_depth': 6, 'learning_rate': 0.010066843844295958, 'subsample': 0.8084323151365935, 'colsample_bytree': 0.6683510997271442, 'gamma': 0.5886495867362136, 'min_child_weight': 8}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:54,033] Trial 31 finished with value: 165.50466144488354 and parameters: {'n_estimators': 301, 'max_depth': 10, 'learning_rate': 0.0924264408168278, 'subsample': 0.6544594016068479, 'colsample_bytree': 0.6362567742496482, 'gamma': 0.4615980585491589, 'min_child_weight': 6}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:13:57,871] Trial 32 finished with value: 166.58342472061295 and parameters: {'n_estimators': 291, 'max_depth': 9, 'learning_rate': 0.09105384633099668, 'subsample': 0.6031391439929366, 'colsample_bytree': 0.6322487747867098, 'gamma': 0.4421366551869182, 'min_child_weight': 6}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:02,030] Trial 33 finished with value: 166.58804714922272 and parameters: {'n_estimators': 378, 'max_depth': 8, 'learning_rate': 0.08508673035014912, 'subsample': 0.6615480503437103, 'colsample_bytree': 0.685771429399263, 'gamma': 0.7776734130981133, 'min_child_weight': 8}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:08,652] Trial 34 finished with value: 166.7807315840477 and parameters: {'n_estimators': 441, 'max_depth': 10, 'learning_rate': 0.12073948368517033, 'subsample': 0.6498650144591331, 'colsample_bytree': 0.6332434417909324, 'gamma': 0.4983624525670554, 'min_child_weight': 1}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:12,603] Trial 35 finished with value: 165.31911868095762 and parameters: {'n_estimators': 252, 'max_depth': 10, 'learning_rate': 0.061399435149488216, 'subsample': 0.688356926961511, 'colsample_bytree': 0.7397992449909506, 'gamma': 0.21089424886682773, 'min_child_weight': 7}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:16,323] Trial 36 finished with value: 167.72954499379895 and parameters: {'n_estimators': 205, 'max_depth': 10, 'learning_rate': 0.029504351570937858, 'subsample': 0.688117961843185, 'colsample_bytree': 0.7476538408387239, 'gamma': 0.2128789171486544, 'min_child_weight': 7}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:19,065] Trial 37 finished with value: 167.2114118146497 and parameters: {'n_estimators': 238, 'max_depth': 8, 'learning_rate': 0.09290170253793822, 'subsample': 0.6015671174996073, 'colsample_bytree': 0.7882798349099456, 'gamma': 0.8860575318164586, 'min_child_weight': 9}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:21,776] Trial 38 finished with value: 167.30934664511062 and parameters: {'n_estimators': 176, 'max_depth': 10, 'learning_rate': 0.14909606679452347, 'subsample': 0.6333504292813594, 'colsample_bytree': 0.7252302027008857, 'gamma': 0.6440997304901958, 'min_child_weight': 6}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:25,104] Trial 39 finished with value: 166.30699445445313 and parameters: {'n_estimators': 256, 'max_depth': 9, 'learning_rate': 0.1111081371988469, 'subsample': 0.6815048267269305, 'colsample_bytree': 0.8117950140020216, 'gamma': 0.01959697887179379, 'min_child_weight': 9}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:28,669] Trial 40 finished with value: 165.57004741813506 and parameters: {'n_estimators': 222, 'max_depth': 10, 'learning_rate': 0.05946196994026267, 'subsample': 0.6552480317556458, 'colsample_bytree': 0.7684145859100543, 'gamma': 0.18482875651586025, 'min_child_weight': 8}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:32,214] Trial 41 finished with value: 165.90153261189917 and parameters: {'n_estimators': 218, 'max_depth': 10, 'learning_rate': 0.05759030528672659, 'subsample': 0.651688440579899, 'colsample_bytree': 0.7763572932943017, 'gamma': 0.17223618432663584, 'min_child_weight': 8}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:34,935] Trial 42 finished with value: 168.3043973971901 and parameters: {'n_estimators': 150, 'max_depth': 10, 'learning_rate': 0.03653620820869784, 'subsample': 0.6826073184132084, 'colsample_bytree': 0.7633576756896551, 'gamma': 0.24922231469245104, 'min_child_weight': 7}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:38,809] Trial 43 finished with value: 166.12748111093074 and parameters: {'n_estimators': 296, 'max_depth': 9, 'learning_rate': 0.08193198086117015, 'subsample': 0.6240791764680899, 'colsample_bytree': 0.7273069464322204, 'gamma': 0.15572019565457576, 'min_child_weight': 10}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:43,102] Trial 44 finished with value: 165.0450342178863 and parameters: {'n_estimators': 261, 'max_depth': 10, 'learning_rate': 0.06364300648319417, 'subsample': 0.7438454963090427, 'colsample_bytree': 0.8250480198493794, 'gamma': 0.708768956029683, 'min_child_weight': 8}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:46,638] Trial 45 finished with value: 165.6314083985398 and parameters: {'n_estimators': 265, 'max_depth': 9, 'learning_rate': 0.10069068888861207, 'subsample': 0.7418516039809363, 'colsample_bytree': 0.8679668985798462, 'gamma': 0.729140794202474, 'min_child_weight': 5}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:50,095] Trial 46 finished with value: 167.261813566406 and parameters: {'n_estimators': 343, 'max_depth': 7, 'learning_rate': 0.08028738242143527, 'subsample': 0.7271529164463779, 'colsample_bytree': 0.9712735987395045, 'gamma': 0.8148502792342921, 'min_child_weight': 6}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:54,476] Trial 47 finished with value: 165.40844154374017 and parameters: {'n_estimators': 295, 'max_depth': 10, 'learning_rate': 0.11875181899696677, 'subsample': 0.7059379101506458, 'colsample_bytree': 0.8202409767849789, 'gamma': 0.7043695867419946, 'min_child_weight': 9}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:14:58,691] Trial 48 finished with value: 166.64432103963048 and parameters: {'n_estimators': 330, 'max_depth': 9, 'learning_rate': 0.13863595189397482, 'subsample': 0.7008145702898468, 'colsample_bytree': 0.9136836154723587, 'gamma': 0.7036655693123807, 'min_child_weight': 9}. Best is trial 5 with value: 164.81076237268059.
# [I 2025-04-14 12:15:03,049] Trial 49 finished with value: 165.27190808209463 and parameters: {'n_estimators': 276, 'max_depth': 10, 'learning_rate': 0.11851311574102999, 'subsample': 0.7513860214046051, 'colsample_bytree': 0.8431664890258521, 'gamma': 0.9559616922194929, 'min_child_weight': 9}. Best is trial 5 with value: 164.81076237268059.
# Best trial:
#   MSE: 164.81076237268059
#   Params:
#     n_estimators: 328
#     max_depth: 10
#     learning_rate: 0.11116473065069664
#     subsample: 0.7747560020066265
#     colsample_bytree: 0.984507091396946
#     gamma: 0.9086645473688747
#     min_child_weight: 1
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.984507091396946, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.9086645473688747, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.11116473065069664,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=328, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
optimized_pred = optimized_xgb.predict(xgb_X_test)
optimized_metrics = evaluate_metrics(y_test,  optimized_pred) # 評価
display(optimized_metrics)
# Out:
#           MSE      RMSE       R2
# 0  164.810762  9.236183  0.77602

# %%
Predict_y = optimized_xgb.predict(predict_X)

# %%
predict_df = pd.DataFrame(Predict_y, columns=['Listening_Time_minutes'])

submission = pd.concat([passenger_id, predict_df], axis=1)

display(submission.head())
# Out:
#        id  Listening_Time_minutes
# 0  750000               55.363472
# 1  750001               18.945518
# 2  750002               49.873425
# 3  750003               72.027771
# 4  750004               47.786980

# %%
submission.to_csv('data/submission.csv', index=False)
